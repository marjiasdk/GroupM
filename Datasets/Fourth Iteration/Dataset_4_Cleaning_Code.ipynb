# %%
import numpy as np
import pandas as pd
from textblob import Word

# %%
df_1 = pd.read_csv("symptomsDisease246k.csv")

df_1
# Out:
#                                                     query  \
# 0       anxiety and nervousness ,shortness of breath ,...
# 1       shortness of breath ,depressive or psychotic s...
# 2       anxiety and nervousness ,depression ,shortness...
# 3       anxiety and nervousness ,depressive or psychot...
# 4       anxiety and nervousness ,depression ,insomnia ...
# ...                                                   ...
# 246940        diminished hearing ,facial pain ,nosebleed
# 246941                     diminished hearing ,nosebleed
# 246942                     diminished hearing ,nosebleed
# 246943           diminished hearing ,headache ,nosebleed
# 246944                   diminished hearing ,facial pain
#
#                       response
# 0               panic disorder
# 1               panic disorder
# 2               panic disorder
# 3               panic disorder
# 4               panic disorder
# ...                        ...
# 246940  open wound of the nose
# 246941  open wound of the nose
# 246942  open wound of the nose
# 246943  open wound of the nose
# 246944  open wound of the nose
#
# [246945 rows x 2 columns]

# %%
word_counts = df_1['response'].value_counts()

minimum = 1100
maximum = 1220
filtered_words = word_counts[(word_counts > minimum) & (word_counts < maximum)]

(filtered_words)
# Out:
# response
# cystitis                              1219
# vulvodynia                            1218
# nose disorder                         1218
# complex regional pain syndrome        1217
# spondylosis                           1216
# hypoglycemia                          1215
# peripheral nerve disorder             1215
# esophagitis                           1215
# vaginal cyst                          1215
# conjunctivitis due to allergy         1215
# diverticulitis                        1214
# gastrointestinal hemorrhage           1214
# acute bronchitis                      1213
# pneumonia                             1212
# fungal infection of the hair          1212
# infectious gastroenteritis            1212
# spontaneous abortion                  1212
# sprain or strain                      1212
# gout                                  1211
# arthritis of the hip                  1210
# strep throat                          1210
# marijuana abuse                       1210
# injury to the arm                     1209
# liver disease                         1209
# bursitis                              1208
# eczema                                1207
# spinal stenosis                       1207
# acute pancreatitis                    1207
# injury to the leg                     1206
# noninfectious gastroenteritis         1206
# benign prostatic hyperplasia (bph)    1206
# acute bronchiolitis                   1204
# cholecystitis                         1204
# anxiety                               1198
# obstructive sleep apnea (osa)         1196
# concussion                            1191
# dental caries                         1185
# Name: count, dtype: int64

# %%
df_1['response'] = df_1['response'].str.strip()

# %%
classes = ['response', 'cystitis', 'vulvodynia', 'nose disorder', 'complex regional pain syndrome', 'spondylosis', 'hypoglycemia', 
           'peripheral nerve disorder', 'esophagitis', 'vaginal cyst', 'conjunctivitis due to allergy', 'diverticulitis',
           'gastrointestinal hemorrhage', 'acute bronchitis', 'pneumonia', 'fungal infection of the hair', 'infectious gastroenteritis',
           'spontaneous abortion', 'sprain or strain', 'gout']
df_2 = df_1[df_1['response'].isin(classes)]

df_2
# Out:
#                                                     query  \
# 14974   blood in stool ,sharp abdominal pain ,vomiting...
# 14975   nausea ,burning abdominal pain ,decreased appe...
# 14976   vomiting ,headache ,diarrhea ,burning abdomina...
# 14977   blood in stool ,sharp abdominal pain ,vomiting...
# 14978   blood in stool ,sharp abdominal pain ,vomiting...
# ...                                                   ...
# 212821  sharp abdominal pain ,lower abdominal pain ,in...
# 212822  sharp abdominal pain ,intermenstrual bleeding ...
# 212823  spotting or bleeding during pregnancy ,cramps ...
# 212824  sharp abdominal pain ,pain during pregnancy ,b...
# 212825  pain during pregnancy ,problems during pregnan...
#
#                           response
# 14974   infectious gastroenteritis
# 14975   infectious gastroenteritis
# 14976   infectious gastroenteritis
# 14977   infectious gastroenteritis
# 14978   infectious gastroenteritis
# ...                            ...
# 212821        spontaneous abortion
# 212822        spontaneous abortion
# 212823        spontaneous abortion
# 212824        spontaneous abortion
# 212825        spontaneous abortion
#
# [23075 rows x 2 columns]

# %%
df_3 = df_2.reset_index(drop=True)
df_3.dropna()
df_3
# Out:
#                                                    query  \
# 0      blood in stool ,sharp abdominal pain ,vomiting...
# 1      nausea ,burning abdominal pain ,decreased appe...
# 2      vomiting ,headache ,diarrhea ,burning abdomina...
# 3      blood in stool ,sharp abdominal pain ,vomiting...
# 4      blood in stool ,sharp abdominal pain ,vomiting...
# ...                                                  ...
# 23070  sharp abdominal pain ,lower abdominal pain ,in...
# 23071  sharp abdominal pain ,intermenstrual bleeding ...
# 23072  spotting or bleeding during pregnancy ,cramps ...
# 23073  sharp abdominal pain ,pain during pregnancy ,b...
# 23074  pain during pregnancy ,problems during pregnan...
#
#                          response
# 0      infectious gastroenteritis
# 1      infectious gastroenteritis
# 2      infectious gastroenteritis
# 3      infectious gastroenteritis
# 4      infectious gastroenteritis
# ...                           ...
# 23070        spontaneous abortion
# 23071        spontaneous abortion
# 23072        spontaneous abortion
# 23073        spontaneous abortion
# 23074        spontaneous abortion
#
# [23075 rows x 2 columns]

# %%
misspelled_words = df_3[df_3['response'] != df_3['response'].apply(lambda x: Word(x).correct())]

# Count the number of misspelled words
misspelled_count = misspelled_words['response'].nunique()

print("Number of unique misspelled words:", misspelled_count)
# Out:
# Number of unique misspelled words: 0

# %%
df_3.columns.values[0] = 'Symptom'
df_3.columns.values[1] = 'Disease'

# %%
#word_counts = df_3['response'].value_counts()

#print(word_counts)

# %%
df_3.to_csv('New_Cleaned_Dataset4.0.csv', index=True)
