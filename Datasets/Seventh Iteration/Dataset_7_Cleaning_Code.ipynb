# %%
import numpy as py
import pandas as pd

# %%
df_1 = pd.read_csv("symptomsDisease246k.csv")

df_1
# Out:
#                                                     query  \
# 0       anxiety and nervousness ,shortness of breath ,...
# 1       shortness of breath ,depressive or psychotic s...
# 2       anxiety and nervousness ,depression ,shortness...
# 3       anxiety and nervousness ,depressive or psychot...
# 4       anxiety and nervousness ,depression ,insomnia ...
# ...                                                   ...
# 246940        diminished hearing ,facial pain ,nosebleed
# 246941                     diminished hearing ,nosebleed
# 246942                     diminished hearing ,nosebleed
# 246943           diminished hearing ,headache ,nosebleed
# 246944                   diminished hearing ,facial pain
#
#                       response
# 0               panic disorder
# 1               panic disorder
# 2               panic disorder
# 3               panic disorder
# 4               panic disorder
# ...                        ...
# 246940  open wound of the nose
# 246941  open wound of the nose
# 246942  open wound of the nose
# 246943  open wound of the nose
# 246944  open wound of the nose
#
# [246945 rows x 2 columns]

# %%
diseases = df_1["response"].value_counts().head(100).index

df_2 = df_1[df_1["response"].isin(diseases)]

df_2
# Out:
#                                                     query        response
# 0       anxiety and nervousness ,shortness of breath ,...  panic disorder
# 1       shortness of breath ,depressive or psychotic s...  panic disorder
# 2       anxiety and nervousness ,depression ,shortness...  panic disorder
# 3       anxiety and nervousness ,depressive or psychot...  panic disorder
# 4       anxiety and nervousness ,depression ,insomnia ...  panic disorder
# ...                                                   ...             ...
# 243955  itching of skin ,skin dryness, peeling, scalin...          eczema
# 243956                                         skin rash           eczema
# 243957  skin lesion ,allergic reaction ,itching of ski...          eczema
# 243958  cough ,abnormal appearing skin ,skin dryness, ...          eczema
# 243959  cough ,acne or pimples ,itching of skin ,skin ...          eczema
#
# [101903 rows x 2 columns]

# %%
df_2['response'] = df_2['response'].str.strip()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_5244\2794784594.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2['response'] = df_2['response'].str.strip()

# %%
df_3 = df_2.reset_index(drop=True)
df_3.dropna()
df_3
# Out:
#                                                     query        response
# 0       anxiety and nervousness ,shortness of breath ,...  panic disorder
# 1       shortness of breath ,depressive or psychotic s...  panic disorder
# 2       anxiety and nervousness ,depression ,shortness...  panic disorder
# 3       anxiety and nervousness ,depressive or psychot...  panic disorder
# 4       anxiety and nervousness ,depression ,insomnia ...  panic disorder
# ...                                                   ...             ...
# 101898  itching of skin ,skin dryness, peeling, scalin...          eczema
# 101899                                         skin rash           eczema
# 101900  skin lesion ,allergic reaction ,itching of ski...          eczema
# 101901  cough ,abnormal appearing skin ,skin dryness, ...          eczema
# 101902  cough ,acne or pimples ,itching of skin ,skin ...          eczema
#
# [101903 rows x 2 columns]

# %%
misspelled_words = df_3[df_3['response'] != df_3['response'].apply(lambda x: Word(x).correct())]

misspelled_count = misspelled_words['response'].nunique()

print("Number of unique misspelled words:", misspelled_count)
# Out:
# Number of unique misspelled words: 0

# %%
df_3.columns.values[0] = 'Symptom'
df_3.columns.values[1] = 'Disease'

# %%
#word_counts = df_3['response'].value_counts()

#print(word_counts)

# %%
df_3.to_csv('Dataset_8.0.csv', index=True)
