# %%
"""
Importing python modules and libraries.
"""

import numpy as np
import pandas as pd
from textblob import Word

# %%
df_1 = pd.read_csv("New_Cleaned_Dataset2.0.csv") # Reading the CSV file

df_1 # Printing CSV file contents
# Out:
#      Unnamed: 0                                            Symptom  \
# 0             0  depressive or psychotic symptoms ,abnormal inv...
# 1             1  depressive or psychotic symptoms ,abnormal inv...
# 2             2  abnormal involuntary movements ,vomiting ,head...
# 3             3  depressive or psychotic symptoms ,abnormal inv...
# 4             4  abnormal involuntary movements ,lack of growth...
# ..          ...                                                ...
# 772         772  back pain ,muscle pain ,side pain ,low back cr...
# 773         773   leg pain ,low back pain ,muscle pain ,side pain
# 774         774                hip pain ,back pain ,low back pain
# 775         775                  hip pain ,back pain ,muscle pain
# 776         776               back pain ,low back pain ,side pain
#
#            Disease
# 0    hydrocephalus
# 1    hydrocephalus
# 2    hydrocephalus
# 3    hydrocephalus
# 4    hydrocephalus
# ..             ...
# 772        lumbago
# 773        lumbago
# 774        lumbago
# 775        lumbago
# 776        lumbago
#
# [777 rows x 3 columns]

# %%
#word_counts = df_1['response'].value_counts()

#minimum = 150
#maximum = 200
# = word_counts[(word_counts > minimum) & (word_counts < maximum)]

#(filtered_words)

# %%
df_1['response'] = df_1['response'].str.strip()
df_1['response']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'response'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-5-31a36d0d595b> in <cell line: 0>()
# ----> 1 df_1['response'] = df_1['response'].str.strip()
#       2 df_1['response']
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4100             if self.columns.nlevels > 1:
#    4101                 return self._getitem_multilevel(key)
# -> 4102             indexer = self.columns.get_loc(key)
#    4103             if is_integer(indexer):
#    4104                 indexer = [indexer]
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3810             ):
#    3811                 raise InvalidIndexError(key)
# -> 3812             raise KeyError(key) from err
#    3813         except TypeError:
#    3814             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'response'

# %%
classes = ['vulvar disorder', 'lumbago', 'hydrocephalus', 'stomach cancer', 'celiac disease']
df_2 = df_1[df_1['response'].isin(classes)]

df_2
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'response'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-6-5c4eb3116476> in <cell line: 0>()
#       1 classes = ['vulvar disorder', 'lumbago', 'hydrocephalus', 'stomach cancer', 'celiac disease']
# ----> 2 df_2 = df_1[df_1['response'].isin(classes)]
#       3
#       4 df_2
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4100             if self.columns.nlevels > 1:
#    4101                 return self._getitem_multilevel(key)
# -> 4102             indexer = self.columns.get_loc(key)
#    4103             if is_integer(indexer):
#    4104                 indexer = [indexer]
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3810             ):
#    3811                 raise InvalidIndexError(key)
# -> 3812             raise KeyError(key) from err
#    3813         except TypeError:
#    3814             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'response'

# %%
df_3 = df_2.reset_index(drop=True)
df_3.dropna()
df_3
# Out:
#                                                  query       response
# 0    depressive or psychotic symptoms ,abnormal inv...  hydrocephalus
# 1    depressive or psychotic symptoms ,abnormal inv...  hydrocephalus
# 2    abnormal involuntary movements ,vomiting ,head...  hydrocephalus
# 3    depressive or psychotic symptoms ,abnormal inv...  hydrocephalus
# 4    abnormal involuntary movements ,lack of growth...  hydrocephalus
# ..                                                 ...            ...
# 772  back pain ,muscle pain ,side pain ,low back cr...        lumbago
# 773   leg pain ,low back pain ,muscle pain ,side pain         lumbago
# 774                hip pain ,back pain ,low back pain         lumbago
# 775                  hip pain ,back pain ,muscle pain         lumbago
# 776               back pain ,low back pain ,side pain         lumbago
#
# [777 rows x 2 columns]

# %%
misspelled_words = df_3[df_3['response'] != df_3['response'].apply(lambda x: Word(x).correct())]

# Count the number of misspelled words
misspelled_count = misspelled_words['response'].nunique()

print("Number of unique misspelled words:", misspelled_count)
# Out:
# Number of unique misspelled words: 0

# %%
df_3.columns.values[0] = 'Symptom'
df_3.columns.values[1] = 'Disease'

df_3

# %%
#word_counts = df_3['response'].value_counts()

#print(word_counts)

# %%
#df_3.to_csv('New_Cleaned_Dataset.csv', index=True)
